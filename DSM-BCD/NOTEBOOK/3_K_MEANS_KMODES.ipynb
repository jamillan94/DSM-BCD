# %% [markdown]
# # Data Science Methodology for Breast Cancer Diagnosis (DSM-BCD)

# %% [markdown]
# **Problema.** Colombia presenta limitaciones con respecto al acceso de la detección y el diagnóstico temprano del cáncer, provocado en la mayoría de los casos por factores como el estrato socio-económico, la cobertura del seguro de salud, el origen y la accesibilidad. En promedio, el tiempo de espera de un paciente es de 90 días desde la aparición de los síntomas hasta el diagnóstico de dicho cáncer. La primera acción para reducir la tasa de mortalidad por cáncer de mama debe estar enfocada en la agilidad del diagnóstico y el acceso oportuno a la atención.  Así, el objetivo de esta investigación es aplicar las etapas de la metodología KDD\footnote{Knowledge Discovery in Databases} al conjunto de datos de morbilidad por cáncer entre los años 2019 y 2020 en el municipio de Pereira-Risaralda. Esto con la finalidad de pronosticar y caracterizar el tipo de población mas susceptible de padecer esta enfermedad según su edad, genero, zona y régimen de salud.

# %% [markdown]
# **Conjunto de datos.** Un total de 817 muestras de tumores de mama se perfilaron con cinco plataformas diferentes como se ha descrito previamente (Cancer Genome Atlas Research Network, 2014) y también se perfilaron 633 casos mediante matriz de proteínas en fase inversa (RPPA)
#
# **1.Study ID**
# **2.Patient ID**
# **3.Sample ID**
# **4.Diagnosis Age**
# **5.American Joint Committee on Cancer Metastasis Stage Code**
# **6.Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code**
# **7.Neoplasm Disease Stage American Joint Committee on Cancer Code**
# **8.American Joint Committee on Cancer Publication Version Type**
# **9.American Joint Committee on Cancer Tumor Stage Code**
# **10.Brachytherapy first reference point administered total dose**
# **11.Cancer Type**
# **12.Cancer Type Detailed**
# **13.Cent17 Copy Number**
# **14.Birth from Initial Pathologic Diagnosis Date**
# **15.Days to Sample Collection.**
# **16.Death from Initial Pathologic Diagnosis Date**
# **17.Last Alive Less Initial Pathologic Diagnosis Date Calculated Day Value**
# **18.Days to Last Followup**
# **19.Disease Free (Months)**
# **20.Disease Free Status**
# **21.Disease code**
# **22.ER positivity scale other**
# **23.ER positivity scale used**
# **24.ER Status By IHC**
# **25.ER Status IHC Percent Positive**
# **26.Ethnicity Category**
# **27.First surgical procedure other**
# **28.Form completion date**
# **29.Fraction Genome Altered**
# **30.HER2 and cent17 cells count**
# **31.HER2 and cent17 scale other**
# **32.HER2 cent17 ratio**
# **33.HER2 copy number**
# **34.HER2 fish method**
# **35.HER2 fish status**
# **36.HER2 ihc percent positive**
# **37.HER2 ihc score**
# **38.HER2 positivity method text**
# **39.HER2 positivity scale other**
# **40.Neoplasm Histologic Type Name**
# **41.Tumor Other Histologic Subtype**
# **42.Neoadjuvant Therapy Type Administered Prior To Resection Text**
# **43.Prior Cancer Diagnosis Occurence**
# **44.ICD-10 Classification**
# **45.International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code**
# **46.International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code**
# **47.IHC-HER2**
# **48.IHC Score**
# **49.Informed consent verified**
# **50.Year Cancer Initial Diagnosis**
# **51.Is FFPE**
# **52.Primary Lymph Node Presentation Assessment Ind-3**
# **53.Positive Finding Lymph Node Hematoxylin and Eosin Staining Microscopy Count**
# **54.Positive Finding Lymph Node Keratin Immunohistochemistry Staining Method Count**
# **55.Lymph Node(s) Examined Number**
# **56.Margin status reexcision**
# **57.Menopause Status**
# **58.Metastatic Site**
# **59.Metastatic Site Other**
# **60.Metastatic tumor indicator**
# **61.First Pathologic Diagnosis Biospecimen Acquisition Method Type**
# **62.First Pathologic Diagnosis Biospecimen Acquisition Other Method Type**
# **63.Micromet detection by ihc**
# **64.Mutation Count**
# **65.New Neoplasm Event Post Initial Therapy Indicator**
# **66.Nte cent 17 HER2 ratio**
# **67.Nte er ihc intensity score**
# **68.Nte er status**
# **69.Nte er status ihc positive**
# **70.Nte HER2 fish status**
# **71.Nte HER2 positivity ihc score**
# **72.Nte HER2 status**
# **73.Nte HER2 status ihc positive**
# **74.Nte pr ihc intensity score**
# **75.Nte pr status by ihc**
# **76.Nte pr status ihc positive**
# **77.Oct embedded**
# **78.Oncotree Code**
# **79.Overall Survival (Months)**
# **80.Overall Survival Status**
# **81.Other Patient ID**
# **82.Other Sample ID**
# **83.Pathology Report File Name**
# **84.Disease Surgical Margin Status**
# **85.Adjuvant Postoperative Pharmaceutical Therapy Administered Indicator**
# **86.Primary Tumor Site**
# **87.Project code**
# **88.Tissue Prospective Collection Indicator**
# **89.PR positivity define method**
# **90.PR positivity ihc intensity score**
# **91.PR positivity scale other**
# **92.PR positivity scale used**
# **93.PR status by ihc**
# **94.PR status ihc percent positive**
# **95.Race Category**
# **96.Did patient start adjuvant postoperative radiotherapy?**
# **97.Tissue Retrospective Collection Indicator**
# **98.Number of Samples Per Patient**
# **99.Sample Type**
# **100.Sex**
# **101.Somatic Status**
# **102.Staging System**
# **103.Staging System_1**
# **104.Surgery for positive margins**
# **105.Surgery for positive margins other**
# **106.Surgical procedure first**
# **107.Tissue Source Site**
# **108.TMB (nonsynonymous)**
# **109.Person Neoplasm Status**
# **110.Tumor Disease Anatomic Site**

# %% [markdown]
# ## Aprendizaje No supervisado

# %% [markdown]
# En el aprendizaje No supervisado, se trabaja con datos sin etiquetar cuya estructura es desconocida. El objetivo será la extracción de información significativa, sin la referencia de variables de salida conocidas, y mediante la exploración de la estructura de dichos datos sin etiquetar. En este caso de estudio se utilizará la siguiente técnica:
#
# ### Agrupamiento (Clustering)
# El agrupamiento es una técnica exploratoria de análisis de datos, que se usa para organizar información en grupos sin tener conocimiento previo de su estructura. Cada grupo es un conjunto de objetos similares que se diferencia de los objetos de otros grupos. El objetivo es obtener un número de grupos de características similares. Los modelos de Clustering más conocidos son los siguientes:
#
# #### K-means:
# Es un algoritmo diseñado para dividir datos no etiquetados en un cierto número (k) de agrupaciones distintas. En otras palabras, k-means encuentra observaciones que comparten características importantes, las une y las clasifica en grupos.
#
# #### K-modes:
# El algoritmo de agrupación de k-modes es una extensión del
# algoritmo k-means. Este algoritmo fue diseñado para agrupar grandes conjuntos de datos categóricos, y tiene como objetivo obtener las k modas que
# representan a un conjunto de datos determinado.

# %% [markdown]
# ## Desarrollo Clustering

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
with open('breast_clean_TCGA.csv') as f:
    dataset=pd.read_csv(f, delimiter=',')

# %%
dataset.head(10)
# Out:
#    diagnosis_age american_joint_committee_on_cancer_metastasis_stage_code  \
# 0           70.0                                                 M0
# 1           59.0                                                 M0
# 2           56.0                                                 M0
# 3           54.0                                                 M0
# 4           39.0                                                 M0
# 5           52.0                                                 M0
# 6           39.0                                                 M0
# 7           54.0                                                 M0
# 8           77.0                                                 M0
# 9           50.0                                                 MX
#
#   neoplasm_disease_lymph_node_stage_american_joint_committee_on_cancer_code  \
# 0                                                 N0
# 1                                                 N0
# ...

# %%
dataset.shape
# Out:
# (818, 84)

# %%
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (777, 84)
# Unseen Data For Predictions: (41, 84)

# %%
from pycaret.clustering import *

exp_clu101 = setup(data, normalize = True, 
                   session_id = 123)
# Out:
# <style type="text/css">
# #T_02934_row2_col1, #T_02934_row21_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_02934_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02934_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_02934_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_02934_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_02934_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_02934_row1_col0" class="data row1 col0" >Original Data</td>
#       <td id="T_02934_row1_col1" class="data row1 col1" >(777, 84)</td>
#     </tr>
#     <tr>
#       <th id="T_02934_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
models()
# Out:
#                                        Name  \
# ID
# kmeans                   K-Means Clustering
# ap                     Affinity Propagation
# meanshift             Mean Shift Clustering
# sc                      Spectral Clustering
# hclust             Agglomerative Clustering
# dbscan     Density-Based Spatial Clustering
# optics                    OPTICS Clustering
# birch                      Birch Clustering
# kmodes                   K-Modes Clustering
#
#                                                    Reference
# ID
# kmeans                        sklearn.cluster._kmeans.KMeans
# ap         sklearn.cluster._affinity_propagation.Affinity...
# meanshift              sklearn.cluster._mean_shift.MeanShift
# sc              sklearn.cluster._spectral.SpectralClustering
# hclust     sklearn.cluster._agglomerative.AgglomerativeCl...
# dbscan                        sklearn.cluster._dbscan.DBSCAN
# optics                        sklearn.cluster._optics.OPTICS
# ...

# %% [markdown]
# ### K-Means Clustering

# %%
kmeans = create_model('kmeans')
# Out:
#    Silhouette  Calinski-Harabasz  Davies-Bouldin  Homogeneity  Rand Index  \
# 0      0.0531            34.0933          3.0437            0           0
#
#    Completeness
# 0             0

# %%
plot_model(kmeans,plot='cluster')

# %%
plot_model(kmeans, plot = 'elbow')

# %%
plot_model(kmeans, plot = 'silhouette')

# %%
plot_model(kmeans, plot = 'tsne')

# %%
plot_model(kmeans, plot = 'distance')

# %%
plot_model(kmeans, plot = 'distribution')

# %%
kmean_results = assign_model(kmeans)
kmean_results.groupby("Cluster").describe()
# Out:
#           diagnosis_age                                                      \
#                   count       mean        std   min   25%   50%   75%   max
# Cluster
# Cluster 0         383.0  58.631854  13.595993  26.0  47.5  59.0  68.0  90.0
# Cluster 1           5.0  62.400000  18.729656  43.0  45.0  62.0  77.0  85.0
# Cluster 2         181.0  56.574586  13.277015  26.0  46.0  56.0  65.0  90.0
# Cluster 3         207.0  60.961353  12.598677  31.0  52.0  61.0  69.0  90.0
#
#           fraction_genome_altered               ...  \
#                             count         mean  ...
# Cluster                                         ...
# Cluster 0                   383.0  1833.571802  ...
# Cluster 1                     5.0  2083.800000  ...
# Cluster 2                   181.0  3072.889503  ...
# Cluster 3                   207.0  4836.835749  ...
#
#           number_of_samples_per_patient      tmb_nonsynonymous                \
# ...

# %%
#kmean_results.to_csv('kmean_results.csv',index=False)

# %%
for i in range(4):
    cluster = 'Cluster '+ str(i)
    a=kmean_results[kmean_results['Cluster']==cluster]
    a.to_csv('kmean_' + cluster + '.csv',index=False)

# %%
kmean_results=kmean_results.applymap(str)
for i in range(4):
    cluster = 'Cluster '+ str(i)
    print("-------***--------***--------***--------***--------***--------***--------***--------***--------")
    print(" CLUSTER " + str(i))
    print("-------***--------***--------***--------***--------***--------***--------***--------***--------")
    print(kmean_results[kmean_results['Cluster']==cluster]['diagnosis_age'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['american_joint_committee_on_cancer_metastasis_stage_code'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['neoplasm_disease_lymph_node_stage_american_joint_committee_on_cancer_code'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['neoplasm_disease_stage_american_joint_committee_on_cancer_code'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['american_joint_committee_on_cancer_tumor_stage_code'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['cancer_type_detailed'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['cent_17_copy_number'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['disease_free_status'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['er_positivity_scale_other'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['er_positivity_scale_used'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['er_status_by_ihc'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['er_status_ihc_percent_positive'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['ethnicity_category'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['first_surgical_procedure_other'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['fraction_genome_altered'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['her_2_and_cent_17_cells_count'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['her_2_and_cent_17_scale_other'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['her_2_cent_17_ratio'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['her_2_copy_number'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['her_2_fish_method'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['her_2_fish_status'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['her_2_ihc_percent_positive'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['her_2_ihc_score'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['her_2_positivity_method_text'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['her_2_positivity_scale_other'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['neoplasm_histologic_type_name'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['tumor_other_histologic_subtype'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['neoadjuvant_therapy_type_administered_prior_to_resection_text'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['prior_cancer_diagnosis_occurence'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['icd_10_classification'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['ihc_her_2'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['ihc_score'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['primary_lymph_node_presentation_assessment_ind_3'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['positive_finding_lymph_node_hematoxylin_and_eosin_staining_microscopy_count'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['positive_finding_lymph_node_keratin_immunohistochemistry_staining_method_count'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['lymph_node_s_examined_number'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['margin_status_reexcision'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['menopause_status'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['metastatic_site'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['metastatic_site_other'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['metastatic_tumor_indicator'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['first_pathologic_diagnosis_biospecimen_acquisition_method_type'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['first_pathologic_diagnosis_biospecimen_acquisition_other_method_type'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['micromet_detection_by_ihc'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['mutation_count'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['new_neoplasm_event_post_initial_therapy_indicator'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['nte_cent_17_her_2_ratio'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['nte_er_ihc_intensity_score'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['nte_er_status'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['nte_er_status_ihc_positive'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['nte_her_2_fish_status'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['nte_her_2_positivity_ihc_score'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['nte_her_2_status'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['nte_her_2_status_ihc_positive'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['nte_pr_ihc_intensity_score'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['nte_pr_status_by_ihc'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['nte_pr_status_ihc_positive'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['oct_embedded'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['oncotree_code'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['overall_survival_status'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['disease_surgical_margin_status'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['adjuvant_postoperative_pharmaceutical_therapy_administered_indicator'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['primary_tumor_site'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['tissue_prospective_collection_indicator'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['pr_positivity_define_method'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['pr_positivity_ihc_intensity_score'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['pr_positivity_scale_other'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['pr_positivity_scale_used'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['pr_status_by_ihc'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['pr_status_ihc_percent_positive'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['race_category'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['did_patient_start_adjuvant_postoperative_radiotherapy'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['tissue_retrospective_collection_indicator'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['number_of_samples_per_patient'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['sample_type'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['sex'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['staging_system'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['staging_system_1'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['surgery_for_positive_margins'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['surgery_for_positive_margins_other'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['surgical_procedure_first'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['tissue_source_site'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['tmb_nonsynonymous'].value_counts()[0:1])
    print(kmean_results[kmean_results['Cluster']==cluster]['person_neoplasm_status'].value_counts()[0:1])
# Out:
# -------***--------***--------***--------***--------***--------***--------***--------***--------
#  CLUSTER 0
# -------***--------***--------***--------***--------***--------***--------***--------***--------
# 62.0    19
# Name: diagnosis_age, dtype: int64
# M0    337
# Name: american_joint_committee_on_cancer_metastasis_stage_code, dtype: int64
# N0    136
# Name: neoplasm_disease_lymph_node_stage_american_joint_committee_on_cancer_code, dtype: int64
# Stage IIA    136
# Name: neoplasm_disease_stage_american_joint_committee_on_cancer_code, dtype: int64
# T2    194
# Name: american_joint_committee_on_cancer_tumor_stage_code, dtype: int64
# Breast Invasive Ductal Carcinoma    200
# Name: cancer_type_detailed, dtype: int64
# nan    358
# Name: cent_17_copy_number, dtype: int64
# 0:DiseaseFree    327
# Name: disease_free_status, dtype: int64
# nan    280
# Name: er_positivity_scale_other, dtype: int64
# nan    331
# Name: er_positivity_scale_used, dtype: int64
# Positive    332
# ...

# %% [markdown]
# ### K-Modes Clustering

# %%
kmodes = create_model('kmodes', num_clusters = 5)
# Out:
#    Silhouette  Calinski-Harabasz  Davies-Bouldin  Homogeneity  Rand Index  \
# 0      0.0317            14.4338          3.6578            0           0
#
#    Completeness
# 0             0

# %%
plot_model(kmodes,plot='cluster')

# %%
plot_model(kmodes, plot = 'elbow')

# %%
plot_model(kmodes, plot = 'silhouette')

# %%
plot_model(kmodes, plot = 'tsne')

# %%
plot_model(kmodes, plot = 'distribution')

# %%
kmodes_results = assign_model(kmodes)
kmodes_results
kmodes_results.groupby("Cluster").describe()
# Out:
#           diagnosis_age                                                        \
#                   count       mean        std   min    25%   50%    75%   max
# Cluster
# Cluster 0         457.0  57.330416  13.448497  26.0  47.00  58.0  66.00  90.0
# Cluster 1         112.0  58.839286  13.100137  34.0  49.00  58.0  65.25  90.0
# Cluster 2         118.0  62.949153  13.076270  33.0  53.25  62.5  74.00  90.0
# Cluster 3          88.0  60.795455  12.450508  37.0  50.00  62.0  69.25  90.0
# Cluster 4           1.0  59.000000        NaN  59.0  59.00  59.0  59.00  59.0
#
#           fraction_genome_altered               ...  \
#                             count         mean  ...
# Cluster                                         ...
# Cluster 0                   456.0  3096.131579  ...
# Cluster 1                   112.0  4050.419643  ...
# Cluster 2                   118.0  1917.940678  ...
# Cluster 3                    89.0  1994.977528  ...
# ...
