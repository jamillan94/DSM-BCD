# %% [markdown]
# # Data Science Methodology for Breast Cancer Diagnosis (DSM-BCD)

# %% [markdown]
# **Problema.** Colombia presenta limitaciones con respecto al acceso de la detección y el diagnóstico temprano del cáncer, provocado en la mayoría de los casos por factores como el estrato socio-económico, la cobertura del seguro de salud, el origen y la accesibilidad. En promedio, el tiempo de espera de un paciente es de 90 días desde la aparición de los síntomas hasta el diagnóstico de dicho cáncer. La primera acción para reducir la tasa de mortalidad por cáncer de mama debe estar enfocada en la agilidad del diagnóstico y el acceso oportuno a la atención.  Así, el objetivo de esta investigación es aplicar las etapas de la metodología KDD\footnote{Knowledge Discovery in Databases} al conjunto de datos de morbilidad por cáncer entre los años 2019 y 2020 en el municipio de Pereira-Risaralda. Esto con la finalidad de pronosticar y caracterizar el tipo de población mas susceptible de padecer esta enfermedad según su edad, genero, zona y régimen de salud.

# %% [markdown]
# **Conjunto de datos.** Un total de 817 muestras de tumores de mama se pedtilaron con cinco plataformas diferentes como se ha descrito previamente (Cancer Genome Atlas Research Network, 2014) y también se pedtilaron 633 casos mediante matriz de proteínas en fase inversa (RPPA)

# %% [markdown]
# ## Aprendizaje Supervisado

# %% [markdown]
# ### Multiclass Classification
# En el aprendizaje No supervisado, se trabaja con datos sin etiquetar cuya estructura es desconocida. El objetivo será la extracción de información significativa, sin la referencia de variables de salida conocidas, y mediante la exploración de la estructura de dichos datos sin etiquetar

# %% [markdown]
# ## Desarrollo Multiclass Classification

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
with open('Breast_Clean_Data.csv') as f:
    dataset=pd.read_csv(f, delimiter=',')

# %%
dataset.head(10)
# Out:
#    diagnosis_age metastasis_stage_code neoplasm_lymph_code  \
# 0           70.0                    m0                  n0
# 1           59.0                    m0                  n0
# 2           56.0                    m0             n0 (i-)
# 3           54.0                    m0                  n0
# 4           39.0                    m0             n0 (i-)
# 5           52.0                    m0                 n1a
# 6           39.0                    m0                 n1a
# 7           54.0                    m0             n0 (i-)
# 8           77.0                    m0             n0 (i-)
# 9           50.0                    mx                  n1
#
#   neoplasm_disease_stage_code tumor_stage_code  \
# 0                     stage i              t1c
# 1                   stage iia               t2
# 2                     stage i              t1c
# 3                   stage iia               t2
# 4                   stage iia               t2
# 5                   stage iib               t2
# 6                  stage iiia               t3
# 7                   stage iia               t2
# 8                   stage iia               t2
# 9                   stage iia              t1c
#
#                         cancer_type_detailed  disease_free_months  \
# 0                  invasive breast carcinoma                  8.5
# 1           breast invasive ductal carcinoma                 14.4
# 2          breast invasive lobular carcinoma                 43.4
# 3           breast invasive ductal carcinoma                 48.1
# 4  breast mixed ductal and lobular carcinoma                 47.2
# 5           breast invasive ductal carcinoma                 20.9
# 6           breast invasive ductal carcinoma                 13.7
# 7                  invasive breast carcinoma                 38.6
# 8           breast invasive ductal carcinoma                  8.0
# 9           breast invasive ductal carcinoma                 39.3
#
#   disease_free_status er_status_ihc er_status_ihc_percent_positive  ...  \
# 0         diseasefree      positive                         70-79%  ...
# 1         diseasefree      positive                         90-99%  ...
# 2         diseasefree      positive                         80-89%  ...
# 3         diseasefree      positive                         90-99%  ...
# 4         diseasefree      negative                         90-99%  ...
# 5         diseasefree      positive                         50-59%  ...
# 6         diseasefree      positive                         70-79%  ...
# 7         diseasefree      negative                         90-99%  ...
# 8         diseasefree      positive                         20-29%  ...
# 9         diseasefree      positive                         90-99%  ...
#
#   disease_surgical_margin_status  primary_tumor_site  \
# 0                       negative             C50.912
# 1                       positive             C50.912
# 2                       negative             C50.412
# 3                       negative             C50.912
# 4                       negative             C50.212
# 5                       negative             C50.911
# 6                       negative             C50.912
# 7                       positive             C50.411
# 8                       negative             C50.912
# 9                       negative             C50.912
#
#   tissue_prospective_indicator pr_status_ihc              race_category  \
# 0                retrospective      negative                      white
# 1                retrospective      positive                      white
# 2                retrospective      positive                      white
# 3                retrospective      positive                      white
# 4                retrospective      positive                      white
# 5                retrospective      positive                      white
# 6                retrospective      positive  black or african american
# 7                retrospective      negative                      asian
# 8                retrospective      negative                      white
# 9                retrospective      positive                      white
#
#       sex                                     staging_system  \
# 0  female                         sentinel node biopsy alone
# 1  female  sentinel lymph node biopsy plus axillary disse...
# 2  female  sentinel lymph node biopsy plus axillary disse...
# 3  female  sentinel lymph node biopsy plus axillary disse...
# 4  female                         sentinel node biopsy alone
# 5  female  sentinel lymph node biopsy plus axillary disse...
# 6  female  sentinel lymph node biopsy plus axillary disse...
# 7  female  sentinel lymph node biopsy plus axillary disse...
# 8    male  sentinel lymph node biopsy plus axillary disse...
# 9  female  sentinel lymph node biopsy plus axillary disse...
#
#       surgical_procedure_first  tmb_nonsynonymous person_neoplasm_status
# 0                   lumpectomy                0.6             tumor free
# 1                   lumpectomy                1.0             tumor free
# 2  modified radical mastectomy                0.7             tumor free
# 3  modified radical mastectomy                1.3             tumor free
# 4                   lumpectomy                2.6             tumor free
# 5                   lumpectomy                5.6             tumor free
# 6  modified radical mastectomy                1.0             tumor free
# 7                   lumpectomy                3.4             tumor free
# 8  modified radical mastectomy                0.7             tumor free
# 9                   lumpectomy                1.5             tumor free
#
# [10 rows x 41 columns]

# %%
dataset.shape
# Out:
# (818, 41)

# %%
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (777, 41)
# Unseen Data For Predictions: (41, 41)

# %%
from pycaret.classification import *
exp_mclf101 = setup(data = data, target = 'oncotree_code', session_id=123)
# Out:
# <style type="text/css">
# #T_22746_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_22746_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22746_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22746_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_22746_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_22746_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_22746_row1_col1" class="data row1 col1" >oncotree_code</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_22746_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_22746_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_22746_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_22746_row3_col1" class="data row3 col1" >brca: 0, idc: 1, ilc: 2, mdlc: 3</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_22746_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_22746_row4_col1" class="data row4 col1" >(777, 41)</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_22746_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_22746_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_22746_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_22746_row6_col1" class="data row6 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_22746_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_22746_row7_col1" class="data row7 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_22746_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_22746_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_22746_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_22746_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_22746_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_22746_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_22746_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_22746_row11_col1" class="data row11 col1" >(543, 135)</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_22746_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_22746_row12_col1" class="data row12 col1" >(234, 135)</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_22746_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_22746_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_22746_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_22746_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_22746_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_22746_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_22746_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_22746_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_22746_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_22746_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_22746_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_22746_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_22746_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_22746_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_22746_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_22746_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_22746_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_22746_row21_col1" class="data row21 col1" >c096</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_22746_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_22746_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_22746_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_22746_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_22746_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_22746_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_22746_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_22746_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_22746_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_22746_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_22746_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_22746_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_22746_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_22746_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_22746_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_22746_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22746_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_22746_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_22746_row30_col1" class="data row3

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_a995a_ th {
#   text-align: left;
# }
# #T_a995a_row0_col0, #T_a995a_row0_col2, #T_a995a_row1_col0, #T_a995a_row1_col2, #T_a995a_row2_col0, #T_a995a_row2_col2, #T_a995a_row3_col0, #T_a995a_row3_col1, #T_a995a_row3_col3, #T_a995a_row3_col4, #T_a995a_row3_col5, #T_a995a_row3_col6, #T_a995a_row3_col7, #T_a995a_row4_col0, #T_a995a_row4_col1, #T_a995a_row4_col2, #T_a995a_row4_col3, #T_a995a_row4_col4, #T_a995a_row4_col5, #T_a995a_row4_col6, #T_a995a_row4_col7, #T_a995a_row5_col0, #T_a995a_row5_col1, #T_a995a_row5_col2, #T_a995a_row5_col3, #T_a995a_row5_col4, #T_a995a_row5_col5, #T_a995a_row5_col6, #T_a995a_row5_col7, #T_a995a_row6_col0, #T_a995a_row6_col1, #T_a995a_row6_col2, #T_a995a_row6_col3, #T_a995a_row6_col4, #T_a995a_row6_col5, #T_a995a_row6_col6, #T_a995a_row6_col7, #T_a995a_row7_col0, #T_a995a_row7_col1, #T_a995a_row7_col2, #T_a995a_row7_col3, #T_a995a_row7_col4, #T_a995a_row7_col5, #T_a995a_row7_col6, #T_a995a_row7_col7, #T_a995a_row8_col0, #T_a995a_row8_col1, #T_a995a_row8_col2, #T_a995a_row8_col3, #T_a995a_row8_col4, #T_a995a_row8_col5, #T_a995a_row8_col6, #T_a995a_row8_col7, #T_a995a_row9_col0, #T_a995a_row9_col1, #T_a995a_row9_col2, #T_a995a_row9_col3, #T_a995a_row9_col4, #T_a995a_row9_col5, #T_a995a_row9_col6, #T_a995a_row9_col7, #T_a995a_row10_col0, #T_a995a_row10_col1, #T_a995a_row10_col2, #T_a995a_row10_col3, #T_a995a_row10_col4, #T_a995a_row10_col5, #T_a995a_row10_col6, #T_a995a_row10_col7, #T_a995a_row11_col0, #T_a995a_row11_col1, #T_a995a_row11_col2, #T_a995a_row11_col3, #T_a995a_row11_col4, #T_a995a_row11_col5, #T_a995a_row11_col6, #T_a995a_row11_col7, #T_a995a_row12_col0, #T_a995a_row12_col1, #T_a995a_row12_col2, #T_a995a_row12_col3, #T_a995a_row12_col4, #T_a995a_row12_col5, #T_a995a_row12_col6, #T_a995a_row12_col7, #T_a995a_row13_col0, #T_a995a_row13_col1, #T_a995a_row13_col2, #T_a995a_row13_col3, #T_a995a_row13_col4, #T_a995a_row13_col5, #T_a995a_row13_col6, #T_a995a_row13_col7 {
#   text-align: left;
# }
# #T_a995a_row0_col1, #T_a995a_row0_col3, #T_a995a_row0_col4, #T_a995a_row0_col5, #T_a995a_row0_col6, #T_a995a_row0_col7, #T_a995a_row1_col1, #T_a995a_row1_col3, #T_a995a_row1_col4, #T_a995a_row1_col5, #T_a995a_row1_col6, #T_a995a_row1_col7, #T_a995a_row2_col1, #T_a995a_row2_col3, #T_a995a_row2_col4, #T_a995a_row2_col5, #T_a995a_row2_col6, #T_a995a_row2_col7, #T_a995a_row3_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a995a_row0_col8, #T_a995a_row5_col8, #T_a995a_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_a995a_row1_col8, #T_a995a_row2_col8, #T_a995a_row3_col8, #T_a995a_row4_col8, #T_a995a_row6_col8, #T_a995a_row7_col8, #T_a995a_row9_col8, #T_a995a_row10_col8, #T_a995a_row11_col8, #T_a995a_row12_col8, #T_a995a_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a995a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a995a_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_a995a_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_a995a_row0_col1" class="data row0 col1" >0.9982</td>
#       <td id="T_a995a_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_a995a_row0_col3" class="data row0 col3" >0.9969</td>
#       <td id="T_a995a_row0_col4" class="data row0 col4" >0.9982</td>
#       <td id="T_a995a_row0_col5" class="data row0 col5" >0.9981</td>
#       <td id="T_a995a_row0_col6" class="data row0 col6" >0.9969</td>
#       <td id="T_a995a_row0_col7" class="data row0 col7" >0.9970</td>
#       <td id="T_a995a_row0_col8" class="data row0 col8" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_a995a_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_a995a_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_a995a_row1_col1" class="data row1 col1" >0.9982</td>
#       <td id="T_a995a_row1_col2" class="data row1 col2" >0.9957</td>
#       <td id="T_a995a_row1_col3" class="data row1 col3" >0.9969</td>
#       <td id="T_a995a_row1_col4" class="data row1 col4" >0.9982</td>
#       <td id="T_a995a_row1_col5" class="data row1 col5" >0.9981</td>
#       <td id="T_a995a_row1_col6" class="data row1 col6" >0.9969</td>
#       <td id="T_a995a_row1_col7" class="data row1 col7" >0.9970</td>
#       <td id="T_a995a_row1_col8" class="data row1 col8" >0.1680</td>
#     </tr>
#     <tr>
#       <th id="T_a995a_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_a995a_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_a995a_row2_col1" class="data row2 col1" >0.9982</td>
#       <td id="T_a995a_row2_col2" class="data row2 col2" >0.9968</td>
#       <td id="T_a995a_row2_col3" class="data row2 col3" >0.9969</td>
#       <td id="T_a995a_row2_col4" class="data row2 col4" >0.9982</td>
#       <td id="T_a995a_row2_col5" class="data row2 col5" >0.9981</td>
#       <td id="T_a995a_row2_col6" class="data row2 col6" >0.9969</td>
#       <td id="T_a995a_row2_col7" class="data row2 col7" >0.9970</td>
#       <td id="T_a995a_row2_col8" class="data row2 col8" >0.1630</td>
#     </tr>
#     <tr>
#       <th id="T_a995a_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_a995a_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a995a_row3_col1" class="data row3 col1" >0.9964</td>
#       <td id="T_a995a_row3_col2" class="data row3 col2" >0.9984</td>
#       <td id="T_a995a_row3_col3" class="data row3 col3" >0.9961</td>
#       <td id="T_a995a_row3_col4" class="data row3 col4" >0.9966</td>
#       <td id="T_a995a_row3_col5" class="data row3 col5" >0.9964</td>
#       <td id="T_a995a_row3_col6" class="data row3 col6" >0.9940</td>
#       <td id="T_a995a_row3_col7" class="data row3 col7" >0.9941</td>
#       <td id="T_a995a_row3_col8" class="data row3 col8" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_a995a_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_a995a_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_a995a_row4_col1" class="data row4 col1" >0.9945</td>
#       <td id="T_a995a_row4_col2" class="data row4 col2" >0.9981</td>
#       <td id="T_a995a_row4_col3" class="data row4 col3" >0.9953</td>
#       <td id="T_a995a_row4_col4" class="data row4 col4" >0.9950</td>
#       <td id="T_a995a_row4_col5" class="data row4 col5" >0.9945</td>
#       <td id="T_a995a_row4_col6" class="data row4 col6" >0.9910</td>
#       <td id="T_a995a_row4_col7" class="data row4 col7" >0.9911</td>
#       <td id="T_a995a_row4_col8" class="data row4 col8" >0.1630</td>
#     </tr>
#     <tr>
#       <th id="T_a995a_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_a995a_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_a995a_row5_col1" class="data row5 col1" >0.9927</td>
#       <td id="T_a995a_row5_col2" class="data row5 col2" >0.9946</td>
#       <td id="T_a995a_row5_col3" class="data row5 col3" >0.9945</td>
#       <td id="T_a995a_row5_col4" class="data row5 col4" >0.9933</td>
#       <td id="T_a995a_row5_col5" class="data row5 col5" >0.9927</td>
#       <td id="T_a995a_row5_col6" class="data row5 col6" >0.9880</td>
#       <td id="T_a995a_row5_col7" class="data row5 col7" >0.9882</td>
#       <td id="T_a995a_row5_col8" class="data row5 col8" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_a995a_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_a995a_row6_col0" class="data row6 col0" >Logis

# %% [markdown]
# ### Decision Tree Classifier

# %%
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_ef739_row10_col0, #T_ef739_row10_col1, #T_ef739_row10_col2, #T_ef739_row10_col3, #T_ef739_row10_col4, #T_ef739_row10_col5, #T_ef739_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ef739_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef739_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef739_row0_col0" class="data row0 col0" >0.9818</td>
#       <td id="T_ef739_row0_col1" class="data row0 col1" >0.9783</td>
#       <td id="T_ef739_row0_col2" class="data row0 col2" >0.9688</td>
#       <td id="T_ef739_row0_col3" class="data row0 col3" >0.9824</td>
#       <td id="T_ef739_row0_col4" class="data row0 col4" >0.9814</td>
#       <td id="T_ef739_row0_col5" class="data row0 col5" >0.9694</td>
#       <td id="T_ef739_row0_col6" class="data row0 col6" >0.9700</td>
#     </tr>
#     <tr>
#       <th id="T_ef739_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ef739_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_ef739_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_ef739_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_ef739_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_ef739_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_ef739_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_ef739_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ef739_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ef739_row2_col0" class="data row2 col0" >0.9818</td>
#       <td id="T_ef739_row2_col1" class="data row2 col1" >0.9894</td>
#       <td id="T_ef739_row2_col2" class="data row2 col2" >0.9922</td>
#       <td id="T_ef739_row2_col3" class="data row2 col3" >0.9838</td>
#       <td id="T_ef739_row2_col4" class="data row2 col4" >0.9822</td>
#       <td id="T_ef739_row2_col5" class="data row2 col5" >0.9702</td>
#       <td id="T_ef739_row2_col6" class="data row2 col6" >0.9708</td>
#     </tr>
#     <tr>
#       <th id="T_ef739_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ef739_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_ef739_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_ef739_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_ef739_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_ef739_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_ef739_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_ef739_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ef739_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ef739_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_ef739_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_ef739_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_ef739_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_ef739_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_ef739_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_ef739_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ef739_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ef739_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_ef739_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_ef739_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_ef739_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_ef739_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_ef739_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_ef739_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ef739_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ef739_row6_col0" class="data row6 col0" >0.9815</td>
#       <td id="T_ef739_row6_col1" class="data row6 col1" >0.9891</td>
#       <td id="T_ef739_row6_col2" class="data row6 col2" >0.9919</td>
#       <td id="T_ef739_row6_col3" class="data row6 col3" >0.9835</td>
#       <td id="T_ef739_row6_col4" class="data row6 col4" >0.9819</td>
#       <td id="T_ef739_row6_col5" class="data row6 col5" >0.9700</td>
#       <td id="T_ef739_row6_col6" class="data row6 col6" >0.9706</td>
#     </tr>
#     <tr>
#       <th id="T_ef739_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ef739_row7_col0" class="data row7 col0" >0.9815</td>
#       <td id="T_ef739_row7_col1" class="data row7 col1" >0.9891</td>
#       <td id="T_ef739_row7_col2" class="data row7 col2" >0.9919</td>
#       <td id="T_ef739_row7_col3" class="data row7 col3" >0.9835</td>
#       <td id="T_ef739_row7_col4" class="data row7 col4" >0.9819</td>
#       <td id="T_ef739_row7_col5" class="data row7 col5" >0.9700</td>
#       <td id="T_ef739_row7_col6" class="data row7 col6" >0.9706</td>
#     </tr>
#     <tr>
#       <th id="T_ef739_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ef739_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_ef739_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_ef739_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_ef739_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_ef739_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_ef739_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_ef739_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ef739_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ef739_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_ef739_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_ef739_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_ef739_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_ef739_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_ef739_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_ef739_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ef739_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ef739_row10_col0" class="data row10 col0" >0.9927</td>
#       <td id="T_ef739_row10_col1" class="data row10 col1" >0.9946</td>
#       <td id="T_ef739_row10_col2" class="data row10 col2" >0.9945</td>
#       <td id="T_ef739_row10_col3" class="data row10 col3" >0.9933</td>
#       <td id="T_ef739_row10_col4" class="data row10 col4" >0.9927</td>
#       <td id="T_ef739_row10_col5" class="data row10 col5" >0.9880</td>
#       <td id="T_ef739_row10_col6" class="data row10 col6" >0.9882</td>
#     </tr>
#     <tr>
#       <th id="T_ef739_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ef739_row11_col0" class="data row11 col0" >0.0090</td>
#       <td id="T_ef739_row11_col1" class="data row11 col1" >0.0073</td>
#       <td id="T_ef739_row11_col2" class="data row11 col2" >0.0093</td>
#       <td id="T_ef739_row11_col3" class="data row11 col3" >0.0082</td>
#       <td id="T_ef739_row11_col4" class="data row11 col4" >0.0089</td>
#       <td id="T_ef739_row11_col5" class="data row11 col5" >0.0147</td>
#       <td id="T_ef739_row11_col6" class="data row11 col6" >0.014

# %%
print(dt)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=123, splitter='best')

# %%
tuned_dt = tune_model(dt)
# Out:
# <style type="text/css">
# #T_aca3c_row10_col0, #T_aca3c_row10_col1, #T_aca3c_row10_col2, #T_aca3c_row10_col3, #T_aca3c_row10_col4, #T_aca3c_row10_col5, #T_aca3c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_aca3c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aca3c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aca3c_row0_col0" class="data row0 col0" >0.9818</td>
#       <td id="T_aca3c_row0_col1" class="data row0 col1" >0.9783</td>
#       <td id="T_aca3c_row0_col2" class="data row0 col2" >0.9688</td>
#       <td id="T_aca3c_row0_col3" class="data row0 col3" >0.9824</td>
#       <td id="T_aca3c_row0_col4" class="data row0 col4" >0.9814</td>
#       <td id="T_aca3c_row0_col5" class="data row0 col5" >0.9694</td>
#       <td id="T_aca3c_row0_col6" class="data row0 col6" >0.9700</td>
#     </tr>
#     <tr>
#       <th id="T_aca3c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aca3c_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_aca3c_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_aca3c_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_aca3c_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_aca3c_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_aca3c_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_aca3c_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aca3c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aca3c_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_aca3c_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_aca3c_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_aca3c_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_aca3c_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_aca3c_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_aca3c_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aca3c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aca3c_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_aca3c_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_aca3c_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_aca3c_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_aca3c_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_aca3c_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_aca3c_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aca3c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aca3c_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_aca3c_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_aca3c_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_aca3c_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_aca3c_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_aca3c_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_aca3c_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aca3c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_aca3c_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_aca3c_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_aca3c_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_aca3c_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_aca3c_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_aca3c_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_aca3c_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aca3c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_aca3c_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_aca3c_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_aca3c_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_aca3c_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_aca3c_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_aca3c_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_aca3c_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aca3c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_aca3c_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_aca3c_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_aca3c_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_aca3c_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_aca3c_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_aca3c_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_aca3c_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aca3c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_aca3c_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_aca3c_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_aca3c_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_aca3c_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_aca3c_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_aca3c_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_aca3c_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aca3c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_aca3c_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_aca3c_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_aca3c_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_aca3c_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_aca3c_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_aca3c_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_aca3c_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aca3c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_aca3c_row10_col0" class="data row10 col0" >0.9982</td>
#       <td id="T_aca3c_row10_col1" class="data row10 col1" >0.9978</td>
#       <td id="T_aca3c_row10_col2" class="data row10 col2" >0.9969</td>
#       <td id="T_aca3c_row10_col3" class="data row10 col3" >0.9982</td>
#       <td id="T_aca3c_row10_col4" class="data row10 col4" >0.9981</td>
#       <td id="T_aca3c_row10_col5" class="data row10 col5" >0.9969</td>
#       <td id="T_aca3c_row10_col6" class="data row10 col6" >0.9970</td>
#     </tr>
#     <tr>
#       <th id="T_aca3c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_aca3c_row11_col0" class="data row11 col0" >0.0055</td>
#       <td id="T_aca3c_row11_col1" class="data row11 col1" >0.0065</td>
#       <td id="T_aca3c_row11_col2" class="data row11 col2" >0.0094</td>
#       <td id="T_aca3c_row11_col3" class="data row11 col3" >0.0053</td>
#       <td id="T_aca3c_row11_col4" class="data row11 col4" >0.0056</td>
#       <td id="T_aca3c_row11_col5" class="data row11 col5" >0.0092</td>
#       <td id="T_aca3c_row11_col6" class="data row11 col6" >0.009

# %%
print(tuned_dt)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=6, max_features=1.0, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0001, min_impurity_split=None,
#                        min_samples_leaf=4, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=123, splitter='best')

# %%
plot_model(tuned_dt, plot = 'confusion_matrix')

# %%
plot_model(tuned_dt, plot = 'class_report')

# %%
plot_model(tuned_dt, plot='boundary')

# %%
plot_model(tuned_dt, plot = 'error')

# %%
evaluate_model(tuned_dt)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
final_dt = finalize_model(tuned_dt)
print(final_dt)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=6, max_features=1.0, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0001, min_impurity_split=None,
#                        min_samples_leaf=4, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=123, splitter='best')

# %%
predict_dt=predict_model(final_dt,data=dataset)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b8dc8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8dc8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b8dc8_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_b8dc8_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_b8dc8_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_b8dc8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b8dc8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b8dc8_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_b8dc8_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_b8dc8_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
predict_dt.groupby("Label").describe()
# Out:
#       diagnosis_age                                                      \
#               count       mean        std   min   25%   50%   75%   max
# Label
# brca          112.0  59.185714  13.457701  29.0  48.0  59.0  68.0  90.0
# idc           491.0  57.331976  13.315703  26.0  48.0  57.0  66.0  90.0
# ilc           127.0  62.299213  12.760501  38.0  52.5  62.0  73.0  90.0
# mdlc           88.0  61.579545  12.523744  34.0  54.0  62.5  69.0  87.0
#
#       disease_free_months             ... tmb_nonsynonymous         Score  \
#                     count       mean  ...               75%    max  count
# Label                                 ...
# brca                112.0  39.169643  ...               1.5   28.7  112.0
# idc                 491.0  38.163136  ...               2.2  128.4  491.0
# ilc                 127.0  41.918110  ...               2.0   35.9  127.0
# mdlc                 88.0  35.559091  ...               1.9    8.0   88.0
#
#
#            mean       std   min  25%  50%  75%  max
# Label
# brca   1.000000  0.000000  1.00  1.0  1.0  1.0  1.0
# idc    0.997963  0.022496  0.75  1.0  1.0  1.0  1.0
# ilc    1.000000  0.000000  1.00  1.0  1.0  1.0  1.0
# mdlc   1.000000  0.000000  1.00  1.0  1.0  1.0  1.0
#
# [4 rows x 88 columns]

# %%
#str_list = ['BRCA','IDC','ILC','MDLC']
#for word in str_list:
    #a=predict_dt[predict_dt['Label']==word]
    #a.to_csv(word + '.csv',index=False)
